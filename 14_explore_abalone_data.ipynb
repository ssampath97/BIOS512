# %% [markdown]
# ![](data:image/jpeg;base64,...)

# %% [markdown]
# Create a vector with the following values called `names`.
# - Length
# - Diameter
# - Height
# - Whole_weight
# - Shucked_weight
# - Viscera_weight
# - Shell_weight
# - Rings

# %%
names <- c('Length', 'Diamter', 'Height', 'Whole_weight', 'Shucked_weight', 'Viscera_weight', 'Shell_weight', 'Rings')
names
# Out:
# [1] "Length"         "Diamter"        "Height"         "Whole_weight"
# [5] "Shucked_weight" "Viscera_weight" "Shell_weight"   "Rings"

# %%
library(tidyverse)

# %% [markdown]
# Read in the abalone data. You can retrieve the link from this URL: [abalone data folder](https://archive.ics.uci.edu/ml/machine-learning-databases/abalone/)
#
# We want the `abalone.data` file.
#
# Use the `col_names` argument with the `names` vector from above to set the column names.

# %%
read_csv("https://archive.ics.uci.edu/ml/machine-learning-databases/abalone/abalone.data")
col_names(names)
# Out:
# ── Column specification ────────────────────────────────────────────────────────
# cols(
#   M = col_character(),
#   `0.455` = col_double(),
#   `0.365` = col_double(),
#   `0.095` = col_double(),
#   `0.514` = col_double(),
#   `0.2245` = col_double(),
#   `0.101` = col_double(),
#   `0.15` = col_double(),
#   `15` = col_double()
# )
#      M 0.455 0.365 0.095 0.514  0.2245 0.101  0.15   15
# 1    M 0.350 0.265 0.090 0.2255 0.0995 0.0485 0.070   7
# 2    F 0.530 0.420 0.135 0.6770 0.2565 0.1415 0.210   9
# 3    M 0.440 0.365 0.125 0.5160 0.2155 0.1140 0.155  10
# 4    I 0.330 0.255 0.080 0.2050 0.0895 0.0395 0.055   7
# 5    I 0.425 0.300 0.095 0.3515 0.1410 0.0775 0.120   8
# 6    F 0.530 0.415 0.150 0.7775 0.2370 0.1415 0.330  20
# 7    F 0.545 0.425 0.125 0.7680 0.2940 0.1495 0.260  16
# 8    M 0.475 0.370 0.125 0.5095 0.2165 0.1125 0.165   9
# 9    F 0.550 0.440 0.150 0.8945 0.3145 0.1510 0.320  19
# 10   F 0.525 0.380 0.140 0.6065 0.1940 0.1475 0.210  14
# ...

# %% [markdown]
# Is there any missing data? Use `filter` to find out.

# %% [markdown]
# Make a scatter plot of `Whole_weight` versus `Shucked_weight` and color the points by `Sex`.

# %% [markdown]
# Make a "jitter" chart where the weight catetories are on the `y-axis` and the weight values are on the `x-axis`. Order the chart by median value.
#
# (Hint: Remember `pivot_longer`)
